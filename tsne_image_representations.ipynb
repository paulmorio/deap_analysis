# %% [markdown]
# # Arousal

# %%
import multiprocessing
import pandas as pd
from ggplot import *
import numpy as np
import signalpreprocess as sp 
import time
from sklearn.manifold import TSNE

import random
import math
from decimal import Decimal
import operator as op

import cPickle

st_X, st_y = cPickle.load(open('deap_data/facerep_data.dat', 'rb'))

# Choose some dude
X = np.array(st_X[1])
y = np.array(st_y[1])
y_valence = np.array(sp.data_binarizer([el[0] for el in y],5))
y_arousal = np.array(sp.data_binarizer([el[1] for el in y],5))
y_dominance = np.array(sp.data_binarizer([el[2] for el in y],5))
y_liking = np.array(sp.data_binarizer([el[3] for el in y],5))
y = y_arousal

print X.shape, y.shape

# PANDAS SHIT WE HAVE TO REPLICATE
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = y
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None

print 'Size of the dataframe: {}'.format(df.shape)

# we take a random permutation of the dataset 
#(it was ordered before, so that we can take a subsample to work with instead of all 70000)
rndperm = np.random.permutation(df.shape[0])

n_sne = 2000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity = 5, n_iter=2000)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)

print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)


df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

chart = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=50,alpha=0.9) \
        + ggtitle("tSNE dimensions colored by digit")
chart
# Out:
# (40, 128) (40,)
# Size of the dataframe: (40, 129)
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 40 samples in 0.000s...
# [t-SNE] Computed neighbors for 40 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 0.056377
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.379898
# [t-SNE] Error after 2000 iterations: 0.435536
# t-SNE done! Time elapsed: 0.69633102417 seconds
# <ggplot: (8748782030837)>

# %% [markdown]
# # Valence

# %%
import multiprocessing
import pandas as pd
from ggplot import *
import numpy as np
import signalpreprocess as sp 
import time
from sklearn.manifold import TSNE

import random
import math
from decimal import Decimal
import operator as op

import cPickle

st_X, st_y = cPickle.load(open('deap_data/facerep_data.dat', 'rb'))

# Choose some dude
X = np.array(st_X[1])
y = np.array(st_y[1])
y_valence = np.array(sp.data_binarizer([el[0] for el in y],5))
y_arousal = np.array(sp.data_binarizer([el[1] for el in y],5))
y_dominance = np.array(sp.data_binarizer([el[2] for el in y],5))
y_liking = np.array(sp.data_binarizer([el[3] for el in y],5))
y = y_valence

print X.shape, y.shape

# PANDAS SHIT WE HAVE TO REPLICATE
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = y
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None

print 'Size of the dataframe: {}'.format(df.shape)

# we take a random permutation of the dataset 
#(it was ordered before, so that we can take a subsample to work with instead of all 70000)
rndperm = np.random.permutation(df.shape[0])

n_sne = 2000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity = 5, n_iter=2000)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)

print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)


df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

chart = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=50,alpha=0.9) \
        + ggtitle("tSNE dimensions colored by digit")
chart
# Out:
# (40, 128) (40,)
# Size of the dataframe: (40, 129)
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 40 samples in 0.000s...
# [t-SNE] Computed neighbors for 40 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 0.056377
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.539192
# [t-SNE] Error after 1450 iterations: 0.502292
# t-SNE done! Time elapsed: 0.491871118546 seconds
# <ggplot: (8748781984541)>

# %% [markdown]
# # Dominance

# %%
import multiprocessing
import pandas as pd
from ggplot import *
import numpy as np
import signalpreprocess as sp 
import time
from sklearn.manifold import TSNE

import random
import math
from decimal import Decimal
import operator as op

import cPickle

st_X, st_y = cPickle.load(open('deap_data/facerep_data.dat', 'rb'))

# Choose some dude
X = np.array(st_X[1])
y = np.array(st_y[1])
y_valence = np.array(sp.data_binarizer([el[0] for el in y],5))
y_arousal = np.array(sp.data_binarizer([el[1] for el in y],5))
y_dominance = np.array(sp.data_binarizer([el[2] for el in y],5))
y_liking = np.array(sp.data_binarizer([el[3] for el in y],5))
y = y_dominance

print X.shape, y.shape

# PANDAS SHIT WE HAVE TO REPLICATE
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = y
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None

print 'Size of the dataframe: {}'.format(df.shape)

# we take a random permutation of the dataset 
#(it was ordered before, so that we can take a subsample to work with instead of all 70000)
rndperm = np.random.permutation(df.shape[0])

n_sne = 2000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity = 5, n_iter=2000)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)

print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)


df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

chart = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=50,alpha=0.9) \
        + ggtitle("tSNE dimensions colored by digit")
chart
# Out:
# (40, 128) (40,)
# Size of the dataframe: (40, 129)
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 40 samples in 0.000s...
# [t-SNE] Computed neighbors for 40 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 0.056377
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 94.190346
# [t-SNE] Error after 2000 iterations: 0.539497
# t-SNE done! Time elapsed: 0.705274820328 seconds
# <ggplot: (8748781910725)>

# %% [markdown]
# # Liking

# %%
import multiprocessing
import pandas as pd
from ggplot import *
import numpy as np
import signalpreprocess as sp 
import time
from sklearn.manifold import TSNE

import random
import math
from decimal import Decimal
import operator as op

import cPickle

st_X, st_y = cPickle.load(open('deap_data/facerep_data.dat', 'rb'))

# Choose some dude
X = np.array(st_X[1])
y = np.array(st_y[1])
y_valence = np.array(sp.data_binarizer([el[0] for el in y],5))
y_arousal = np.array(sp.data_binarizer([el[1] for el in y],5))
y_dominance = np.array(sp.data_binarizer([el[2] for el in y],5))
y_liking = np.array(sp.data_binarizer([el[3] for el in y],5))
y = y_liking

print X.shape, y.shape

# PANDAS SHIT WE HAVE TO REPLICATE
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]

df = pd.DataFrame(X,columns=feat_cols)
df['label'] = y
df['label'] = df['label'].apply(lambda i: str(i))

X, y = None, None

print 'Size of the dataframe: {}'.format(df.shape)

# we take a random permutation of the dataset 
#(it was ordered before, so that we can take a subsample to work with instead of all 70000)
rndperm = np.random.permutation(df.shape[0])

n_sne = 2000

time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity = 5, n_iter=2000)
tsne_results = tsne.fit_transform(df.loc[rndperm[:n_sne],feat_cols].values)

print 't-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start)


df_tsne = df.loc[rndperm[:n_sne],:].copy()
df_tsne['x-tsne'] = tsne_results[:,0]
df_tsne['y-tsne'] = tsne_results[:,1]

chart = ggplot( df_tsne, aes(x='x-tsne', y='y-tsne', color='label') ) \
        + geom_point(size=50,alpha=0.9) \
        + ggtitle("tSNE dimensions colored by digit")
chart
# Out:
# (40, 128) (40,)
# Size of the dataframe: (40, 129)
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 40 samples in 0.001s...
# [t-SNE] Computed neighbors for 40 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 40 / 40
# [t-SNE] Mean sigma: 0.056377
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.900810
# [t-SNE] Error after 1400 iterations: 0.467471
# t-SNE done! Time elapsed: 0.48853302002 seconds
# <ggplot: (8748781889541)>
